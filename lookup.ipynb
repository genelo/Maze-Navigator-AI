# %%
def lookup ():
    if double_o_seven.current_y >= 2:
        cost = abs(double_o_seven.current_x - double_o_seven.exit_x) + abs((double_o_seven.current_y-1) - double_o_seven.exit_y)
        cost += abs(double_o_seven.current_x - double_o_seven.exit_x) + abs((double_o_seven.current_y-2) - double_o_seven.exit_y)
        #checking for webs
        for web in total_spider_net:
            if web.get_y() == (double_o_seven.current_y-1) && web.get_x() == double_o_seven.current_x:
                cost += 10000
            if web.get_y() == (double_o_seven.current_y-2) && web.get_x() == double_o_seven.current_x:
                cost += 10000
        #checking for quicksand        
        for i in range(0,(int)(number_of_quick_sands/2)):
            if quick_sand_array[i].get_x() == double_o_seven.current_x && quick_sand_array[i].get_y == (double_o_seven.current_y -1):
                cost +=10000
            if quick_sand_array[i].get_x() == double_o_seven.current_x && quick_sand_array[i].get_y == (double_o_seven.current_y -2):
                cost +=10000
        #checking for tolls
        for fee in fees_array:
            if fee.get_x() == double_o_seven.current_x && fee.get_y() == (double_o_seven.current_y -1):
                cost += fee.get_cost()
            if fee.get_x() == double_o_seven.current_x && fee.get_y() == (double_o_seven.current_y -2):
                cost += fee.get_cost()
        cost /= 2
        
    else if double_o_seven.current_y=1:
        cost = abs(double_o_seven.current_x - double_o_seven.exit_x) + abs((double_o_seven.current_y-1) - double_o_seven.exit_y)
        for web in total_spider_net:
            if web.get_y() == (double_o_seven.current_y-1) && web.get_x() == double_o_seven.current_x:
                cost += 10000
        for i in range(0,(int)(number_of_quick_sands/2)):
            if quick_sand_array[i].get_x() == double_o_seven.current_x && quick_sand_array[i].get_y == (double_o_seven.current_y -1):
                cost +=10000
        for fee in fees_array:
            if fee.get_x() == double_o_seven.current_x && fee.get_y() == (double_o_seven.current_y -1):
                cost += fee.get_cost()
    else if double_o_seven.current_y = 0:
        cost = 10000;
    
    return cost

# %%
def lookdown():
    if double_o_seven.current_y <=17:
        cost = abs(double_o_seven.current_x - double_o_seven.exit_x) + abs((double_o_seven.current_y-1) - double_o_seven.exit_y)
        cost += abs(double_o_seven.current_x - double_o_seven.exit_x) + abs((double_o_seven.current_y-2) - double_o_seven.exit_y)
        #checking for webs
        for web in total_spider_net:
            if web.get_y() == (double_o_seven.current_y+1) && web.get_x() == double_o_seven.current_x:
                cost += 10000
            if web.get_y() == (double_o_seven.current_y+2) && web.get_x() == double_o_seven.current_x:
                cost += 10000
        #checking for quicksand        
        for i in range(0,(int)(number_of_quick_sands/2)):
            if quick_sand_array[i].get_x() == double_o_seven.current_x && quick_sand_array[i].get_y == (double_o_seven.current_y +1):
                cost +=10000
            if quick_sand_array[i].get_x() == double_o_seven.current_x && quick_sand_array[i].get_y == (double_o_seven.current_y +2):
                cost +=10000
        #checking for tolls
        for fee in fees_array:
            if fee.get_x() == double_o_seven.current_x && fee.get_y() == (double_o_seven.current_y +1):
                cost += fee.get_cost()
            if fee.get_x() == double_o_seven.current_x && fee.get_y() == (double_o_seven.current_y +2):
                cost += fee.get_cost()
        cost /= 2
        
    else if double_o_seven.current_y= 18:
        cost = abs(double_o_seven.current_x - double_o_seven.exit_x) + abs((double_o_seven.current_y+1) - double_o_seven.exit_y)
        for web in total_spider_net:
            if web.get_y() == (double_o_seven.current_y+1) && web.get_x() == double_o_seven.current_x:
                cost += 10000
        for i in range(0,(int)(number_of_quick_sands/2)):
            if quick_sand_array[i].get_x() == double_o_seven.current_x && quick_sand_array[i].get_y == (double_o_seven.current_y +1):
                cost +=10000
        for fee in fees_array:
            if fee.get_x() == double_o_seven.current_x && fee.get_y() == (double_o_seven.current_y +1):
                cost += fee.get_cost()
    else if double_o_seven.current_y = 19:
        cost = 10000;
    
    return cost

# %%
def lookright():
    if double_o_seven.current_x >= 17:
        cost = abs((double_o_seven.current_x + 1) - double_o_seven.exit_x) + abs(double_o_seven.current_y - double_o_seven.exit_y)
        cost += abs((double_o_seven.current_x+2) - double_o_seven.exit_x) + abs(double_o_seven.current_y - double_o_seven.exit_y)
        #checking for webs
        for web in total_spider_net:
            if web.get_y() == (double_o_seven.current_y) && web.get_x() == double_o_seven.current_x +1:
                cost += 10000
            if web.get_y() == (double_o_seven.current_y) && web.get_x() == double_o_seven.current_x +2:
                cost += 10000
        #checking for quicksand        
        for i in range(0,(int)(number_of_quick_sands/2)):
            if quick_sand_array[i].get_x() == (double_o_seven.current_x +1) && quick_sand_array[i].get_y == (double_o_seven.current_y ):
                cost +=10000
            if quick_sand_array[i].get_x() == (double_o_seven.current_x+2) &&  quick_sand_array[i].get_y == (double_o_seven.current_y ):
                cost +=10000
        #checking for tolls
        for fee in fees_array:
            if fee.get_x() == (double_o_seven.current_x + 1) && fee.get_y() == (double_o_seven.current_y ):
                cost += fee.get_cost()
            if fee.get_x() == (double_o_seven.current_x + 2) && fee.get_y() == (double_o_seven.current_y ):
                cost += fee.get_cost()
        cost /= 2
        
    else if double_o_seven.current_x=18:
        cost = abs(double_o_seven.current_x - double_o_seven.exit_x) + abs((double_o_seven.current_y) - double_o_seven.exit_y)
        for web in total_spider_net:
            if web.get_y() == (double_o_seven.current_y) && web.get_x() == (double_o_seven.current_x +1):
                cost += 10000
        for i in range(0,(int)(number_of_quick_sands/2)):
            if quick_sand_array[i].get_x() == (double_o_seven.current_x +1) && quick_sand_array[i].get_y == (double_o_seven.current_y):
                cost +=10000
        for fee in fees_array:
            if fee.get_x() == (double_o_seven.current_x+1) && fee.get_y() == (double_o_seven.current_y ):
                cost += fee.get_cost()
    else if double_o_seven.current_x = 19:
        cost = 10000;
    
    return cost

# %%
def lookleft():
    if double_o_seven.current_x <= 2:
        cost = abs((double_o_seven.current_x - 1) - double_o_seven.exit_x) + abs(double_o_seven.current_y - double_o_seven.exit_y)
        cost += abs((double_o_seven.current_x - 2) - double_o_seven.exit_x) + abs(double_o_seven.current_y - double_o_seven.exit_y)
        #checking for webs
        for web in total_spider_net:
            if web.get_y() == (double_o_seven.current_y) && web.get_x() == double_o_seven.current_x - 1:
                cost += 10000
            if web.get_y() == (double_o_seven.current_y) && web.get_x() == double_o_seven.current_x - 2:
                cost += 10000
        #checking for quicksand        
        for i in range(0,(int)(number_of_quick_sands/2)):
            if quick_sand_array[i].get_x() == (double_o_seven.current_x - 1) && quick_sand_array[i].get_y == (double_o_seven.current_y ):
                cost +=10000
            if quick_sand_array[i].get_x() == (double_o_seven.current_x - 2) &&  quick_sand_array[i].get_y == (double_o_seven.current_y ):
                cost +=10000
        #checking for tolls
        for fee in fees_array:
            if fee.get_x() == (double_o_seven.current_x - 1) && fee.get_y() == (double_o_seven.current_y ):
                cost += fee.get_cost()
            if fee.get_x() == (double_o_seven.current_x - 2) && fee.get_y() == (double_o_seven.current_y ):
                cost += fee.get_cost()
        cost /= 2
        
    else if double_o_seven.current_x=1:
        cost = abs(double_o_seven.current_x - double_o_seven.exit_x) + abs((double_o_seven.current_y) - double_o_seven.exit_y)
        for web in total_spider_net:
            if web.get_y() == (double_o_seven.current_y) && web.get_x() == (double_o_seven.current_x - 1):
                cost += 10000
        for i in range(0,(int)(number_of_quick_sands/2)):
            if quick_sand_array[i].get_x() == (double_o_seven.current_x - 1) && quick_sand_array[i].get_y == (double_o_seven.current_y):
                cost +=10000
        for fee in fees_array:
            if fee.get_x() == (double_o_seven.current_x - 1) && fee.get_y() == (double_o_seven.current_y ):
                cost += fee.get_cost()
    else if double_o_seven.current_x = 0:
        cost = 10000;
    
    return cost
